# %% [markdown]
# #Laboratorio 7: Newton Fractals

# %% [markdown]
# Grupo 31
# * Javier Alejandro Ortiz Silva.
# * Gustavo Alberto Puentes Romero
# * Cristian Daniel Ramirez Marin

# %% [markdown]
# ---
#
# *Nota: Las celdas adicionadas se encuentran al final
#
# ---

# %% [markdown]
# # Modification to plot a square in the complex plane with center in (z_c_r, z_c_i) and of size zw x zh
#
# Modfied from Fractals with Python - The Newton Set https://blog.anvetsu.com/posts/fractals-newton-python-matplotlib-numpy/
# from the Fractals with Python series https://blog.anvetsu.com/tags/fractal/
#
# German Hernandez
#
# ![picture](https://raw.githubusercontent.com/gjhernandezp/algorithms/master/Z3_1centermap.png)

# %%
import math
import matplotlib.pyplot as plt
import numpy as np

def f(z):
    return z ** 3 - 1

def df(z):
    return 3 * z**2

def newton_set1(z_c_r=0, z_c_i=0, zh = 5, zw=5, width=500, height=500, zoom=1,  niter=256):
    """ Fractals using newton-raphson """

    # Pixels array
    pixels = np.arange(width*height*3, dtype=np.uint32).reshape(height, width, 3)

    h = 1e-7 # step size for numerical derivative
    eps = 1e-3 # max error allowed

    # Bounding roots
    r1 = 1
    r2 = complex(-0.5, math.sin(2*math.pi/3))
    r3 = complex(-0.5, -1*math.sin(2*math.pi/3))

    # Color multiplication factor
    # NOTE: Increasing this darkens the image and lightens it otherwise
    multcol = 5

    for y in range(height):
            zy =   z_c_i+(((y-(height/2))/height)*zh*zoom)

            for x in range(width):
                zx = z_c_r+ (((x-(width/2))/width)*zw*zoom)

                # Mapping real -> complex plane
                z = complex(zx, zy)
                
                count = 0
                
                for i in range(niter):
                    # complex numerical derivative
                    dz = df(z)
                    if dz == 0:
                        break

                    count += 1
                    if count > 255:
                        break
                   
                    znext = z - f(z) / dz # Newton iteration

                    if abs(znext - z) < eps: # stop when close enough to any root
                        break
                    
                    z = znext

                # Pixels colored using the roots
                if abs(z-r1)<eps:
                    # color red
                    pixels[height-y-1,x] = (255 - count*multcol, 0, 0)
                elif abs(z-r2)<=eps:
                    # color green
                    pixels[height-y-1,x] = (0, 255 - count*multcol, 0)
                elif abs(z-r3)<=eps:
                    # color blue
                    pixels[height-y-1,x] = (0, 0, 255 - count*multcol)
                else:   
                    pixels[height-y-1,x] = (0, 0, 0)
 
    return pixels

def display1(z_c_r=0, z_c_i=0, zh = 1, zw=1, width=500, height=500, zoom=1,  niter=256):
    """ Display a newton-raphson fractal """
    print("Z region from (",z_c_r+ (((0-(width/2))/width)*zw*zoom),",",z_c_i+(((0-(height/2))/height)*zh*zoom) ,") to (",z_c_r+ (((width-(width/2))/width)*zw*zoom),",",z_c_i+(((height-(height/2))/height)*zh*zoom),")")
    pimg = newton_set1(z_c_r=z_c_r, z_c_i=z_c_i, zh = zh, zw=zw, width=width, height=width, zoom=zoom,  niter=niter)
    plt.title('Newton Fractal f(z)=z**3-1')
    plt.xlabel("real"+"("+ str(z_c_r+ (((0-(width/2))/width)*zw*zoom))+","+str(z_c_r+ (((width-(width/2))/width)*zw*zoom))+")")
    plt.ylabel("imaginary"+"("+str(z_c_i+(((0-(height/2))/height)*zh*zoom))+","+str(z_c_i+(((height-(height/2))/height)*zh*zoom)) +")")
    plt.imshow(pimg)
    plt.show()

# %% [markdown]
# ## Plot of f(z)= z\*\*3-1 for the reals f(x)= x\*\*3-1

# %%
x = np.linspace(-2.0,2.0,100)
fig, ax = plt.subplots()
ax.plot(x,f(x))
ax.axhline(y=0, color='k')
ax.axvline(x=0, color='k')
ax.grid(True, which='both')
plt.title('f(x)=x**3-1')
plt.xlabel('x')
plt.ylabel('f(x)')
# Out:
# Text(0, 0.5, 'f(x)')

# %%
print("zoom out")
display1(zoom=1)
display1(zoom=2)
display1(zoom=3)
display1(zoom=4)
display1(zoom=5)

# %%
print("zoom in")
display1(zoom=1)
display1(zoom=1/2)
display1(zoom=1/3)
display1(zoom=1/4)
display1(zoom=1/5)
display1(zoom=1/10)
display1(zoom=1/100)
display1(zoom=1/1000)
# Out:
# zoom in
# Z region from ( -0.5 , -0.5 ) to ( 0.5 , 0.5 )
# Z region from ( -0.25 , -0.25 ) to ( 0.25 , 0.25 )
# Z region from ( -0.16666666666666666 , -0.16666666666666666 ) to ( 0.16666666666666666 , 0.16666666666666666 )
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Z region from ( -0.125 , -0.125 ) to ( 0.125 , 0.125 )
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Z region from ( -0.1 , -0.1 ) to ( 0.1 , 0.1 )
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Z region from ( -0.05 , -0.05 ) to ( 0.05 , 0.05 )
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Z region from ( -0.005 , -0.005 ) to ( 0.005 , 0.005 )
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Z region from ( -0.0005 , -0.0005 ) to ( 0.0005 , 0.0005 )
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# ## Newton iterates form z=10.0 + 0.0j

# %%
z=10.0 + 0.0j
r=[]
i=[]
for k in range(50):
  dz = df(z)
  z = z - f(z) / dz # Newton iteration
  r.append(np.real(z))
  i.append(np.imag(z))
plt.title('Newton iterates form z=10.0 + 0.0j')
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imagnary part')
plt.show()

# %% [markdown]
# ## Newton iterates form z=-10.0 + 10.0j

# %%
z=-10.0 +10.0j
r=[]
i=[]
for k in range(50):
  dz = df(z)
  z = z - f(z) / dz # Newton iteration
  r.append(np.real(z))
  i.append(np.imag(z))
plt.title('Newton iterates form z=-10.0 + 10.0j')
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imagnary part')
plt.show()

# %% [markdown]
# ## Newton iterates form z=-10.0 -10.0j

# %%
z=-10.0 -10.0j
r=[]
i=[]
for k in range(50):
  dz = df(z)
  z = z - f(z) / dz # Newton iteration
  r.append(np.real(z))
  i.append(np.imag(z))
plt.title('Newton iterates form z=-10.0 -10.0j')
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imagnary part')
plt.show()

# %% [markdown]
# ## Newton iterates form z=0.0 + 0.0j

# %%
z=0.0 + 0.0j
r=[]
i=[]
for k in range(100):
  dz = df(z)
  z = z - f(z) / dz # Newton iteration
  r.append(np.real(z))
  i.append(np.imag(z))
plt.title('Newton iterates form z=0.0 + 0.0j')
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imagnary part')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-9-0dd34fb0969d> in <module>()
#       4 for k in range(100):
#       5   dz = df(z)
# ----> 6   z = z - f(z) / dz # Newton iteration
#       7   r.append(np.real(z))
#       8   i.append(np.imag(z))
#
# ZeroDivisionError: complex division by zero

# %% [markdown]
# #**Solución laboratorio**

# %% [markdown]
# ## **Primer Fractal**

# %%
import math
import matplotlib.pyplot as plt
import numpy as np

def f(z):
    return z**6+z**3-1


def df(z):
    return 6*z**5+3*z**2
    

def newton_set1(z_c_r=0, z_c_i=0, zh = 5, zw=5, width=500, height=500, zoom=1,  niter=256):
    """ Fractals using newton-raphson """

    # Pixels array
    pixels = np.arange(width*height*3, dtype=np.uint32).reshape(height, width, 3)

    h = 1e-7 # step size for numerical derivative
    eps = 1e-3 # max error allowed

    # Bounding roots
    r1 = ((-1+5**(1/2))/2)**(1/3)
    r2 = complex(-(2**(2/3)*(-1+5**(1/2))**(1/3))/4,(3**(1/2)*2**(2/3)*(-1+5**(1/2))**(1/3))/4)   
    r3 = complex(-(2**(2/3)*(-1+5**(1/2))**(1/3))/4,-(3**(1/2)*2**(2/3)*(-1+5**(1/2))**(1/3))/4)   
    r4 =  ((-1-5**(1/2))/2)**(1/3)
    r5 = complex(-(2**(2/3)*(-1-5**(1/2))**(1/3))/4,(3**(1/2)*2**(2/3)*(-1-5**(1/2))**(1/3))/4)   
    r6 = complex(-(2**(2/3)*(-1-5**(1/2))**(1/3))/4,-(3**(1/2)*2**(2/3)*(-1-5**(1/2))**(1/3))/4)

    # Color multiplication factor
    # NOTE: Increasing this darkens the image and lightens it otherwise
    multcol = 5

    for y in range(height):
            zy =   z_c_i+(((y-(height/2))/height)*zh*zoom)

            for x in range(width):
                zx = z_c_r+ (((x-(width/2))/width)*zw*zoom)

                # Mapping real -> complex plane
                z = complex(zx, zy)
                
                count = 0
                
                for i in range(niter):
                    # complex numerical derivative
                    dz = df(z)
                    if dz == 0:
                        break

                    count += 1
                    if count > 255:
                        break
                   
                    znext = z - f(z) / dz # Newton iteration

                    if abs(znext - z) < eps: # stop when close enough to any root
                        break
                    
                    z = znext

                # Pixels colored using the roots
                if abs(z-r1)<eps:
                    # color red
                    pixels[height-y-1,x] = (255 - count*multcol, 0, 0)
                elif abs(z-r2)<=eps:
                    # color green
                    pixels[height-y-1,x] = (0, 255 - count*multcol, 0)
                elif abs(z-r3)<=eps:
                    
                    pixels[height-y-1,x] = (0, 0, 255 - count*multcol)
                elif abs(z-r4)<=eps:
                    pixels[height-y-1,x] = (0, 255 - count*multcol, 255 - count*multcol)
                elif abs(z-r5)<=eps:
                    pixels[height-y-1,x] = ( 255 - count*multcol,0, 255 - count*multcol)
                elif abs(z-r6)<=eps:
                    pixels[height-y-1,x] = ( 255 - count*multcol, 255 - count*multcol,0)
                else:   
                    pixels[height-y-1,x] = (0, 0, 0)
 
    return pixels

def display2(z_c_r=0, z_c_i=0, zh = 1, zw=1, width=500, height=500, zoom=1,  niter=256):
    """ Display a newton-raphson fractal """
    print("Z region from (",z_c_r+ (((0-(width/2))/width)*zw*zoom),",",z_c_i+(((0-(height/2))/height)*zh*zoom) ,") to (",z_c_r+ (((width-(width/2))/width)*zw*zoom),",",z_c_i+(((height-(height/2))/height)*zh*zoom),")")
    pimg = newton_set1(z_c_r=z_c_r, z_c_i=z_c_i, zh = zh, zw=zw, width=width, height=width, zoom=zoom,  niter=niter)
    plt.title('Newton Fractal f(z)=z**6+z**3-1')
    plt.xlabel("real"+"("+ str(z_c_r+ (((0-(width/2))/width)*zw*zoom))+","+str(z_c_r+ (((width-(width/2))/width)*zw*zoom))+")")
    plt.ylabel("imaginary"+"("+str(z_c_i+(((0-(height/2))/height)*zh*zoom))+","+str(z_c_i+(((height-(height/2))/height)*zh*zoom)) +")")
    plt.imshow(pimg)
    plt.show()

# %% [markdown]
# **Gráfica**

# %%
x = np.linspace(-2.0,2.0,100)
fig, ax = plt.subplots()
ax.plot(x,f(x))
ax.axhline(y=0, color='k')
ax.axvline(x=0, color='k')
ax.grid(True, which='both')
plt.title('f(x)=x**6+x**3-1')
plt.xlabel('x')
plt.ylabel('f(x)')
# Out:
# Text(0, 0.5, 'f(x)')

# %%
print("zoom out")
display2(zoom=1)
display2(zoom=2)
display2(zoom=3)
display2(zoom=4)
display2(zoom=5)
# Out:
# zoom out
# Z region from ( -0.5 , -0.5 ) to ( 0.5 , 0.5 )
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Z region from ( -1.0 , -1.0 ) to ( 1.0 , 1.0 )
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Z region from ( -1.5 , -1.5 ) to ( 1.5 , 1.5 )
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Z region from ( -2.0 , -2.0 ) to ( 2.0 , 2.0 )
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Z region from ( -2.5 , -2.5 ) to ( 2.5 , 2.5 )
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# ### Newton iterates: z=10.0 + 0.0j

# %%
def fPrimero(z):
    return z**6+z**3-1

def dfPrimero(z):
    return 6*z**5+3*z**2

# %%
z=10.0 + 0.0j
r=[]
i=[]
for k in range(50):
  dz = dfPrimero(z)
  z = z - fPrimero(z) / dz # Newton iteration
  r.append(np.real(z))
  i.append(np.imag(z))
plt.title('Newton iterates: z=10.0 + 0.0j')
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imaginary part')
plt.show()

# %% [markdown]
# ###Newton iterates form z=-10.0 + 10.0j

# %%
z=-10.0 +10.0j
r=[]
i=[]
for k in range(50):
  dz = dfPrimero(z)
  z = z - fPrimero(z) / dz # Newton iteration
  r.append(np.real(z))
  i.append(np.imag(z))
plt.title('Newton iterates: z=-10.0 + 10.0j')
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imaginary part')
plt.show()

# %% [markdown]
# ###Newton iterates: z=-10.0 -10.0j

# %%
z=-10.0 -10.0j
r=[]
i=[]
for k in range(50):
  dz = dfPrimero(z)
  z = z - fPrimero(z) / dz # Newton iteration
  r.append(np.real(z))
  i.append(np.imag(z))
plt.title('Newton iterates form z=-10.0 -10.0j')
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imaginary part')
plt.show()

# %% [markdown]
# ### Newton iterates: z=10.0 + 10.0j

# %%
z=10.0 + 10.0j
r=[]
i=[]
for k in range(100):
  dz = dfPrimero(z)
  z = z - fPrimero(z) / dz # Newton iteration
  r.append(np.real(z))
  i.append(np.imag(z))
plt.title('Newton iterates form z=10.0 + 10.0j')
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imaginary part')
plt.show()

# %% [markdown]
# ###Análisis de resultados
# ________________________________________
#
# *   Se trabajo el fractal generado a través del polinomio = z^6 + z^3 - 1
#
# *   Debido a que el polinomio es de grado 6, se encontraron seis raíces en total, de las cuales dos son reales y cuatro son complejas.
#
#
# *   En la gráfica del fractal es posible evidenciar seis colores (en diversas zonas amplias y delimitadas) correspondientes a los valores que convergen para cada una de las raíces.
# Además, los valores para las tres raíces representadas por los colores: azul, rojo y verde tienen más convergencia con respecto a las demás raíces.

# %% [markdown]
# ##**Segundo fractal**

# %%
import math
import matplotlib.pyplot as plt
import numpy as np

def f(z):
    return z**8+15*z**4-16


def df(z):
    return 8*z**7+60*z**3
    

def newton_set1(z_c_r=0, z_c_i=0, zh = 5, zw=5, width=500, height=500, zoom=1,  niter=256):
    """ Fractals using newton-raphson """

    # Pixels array
    pixels = np.arange(width*height*3, dtype=np.uint32).reshape(height, width, 3)

    h = 1e-7 # step size for numerical derivative
    eps = 1e-3 # max error allowed

    # Bounding roots
    r1 = 1
    r2=-1
    r3=complex(1.4142,1.4142)
    r4=complex(-1.4142,1.4142)
    r5=complex(-1.4142,-1.4142)
    r6=complex(1.4142,-1.4142)
    r7=complex(0,1)
    r8=complex(0,-1)
    # Color multiplication factor
    # NOTE: Increasing this darkens the image and lightens it otherwise
    multcol = 5

    for y in range(height):
            zy =   z_c_i+(((y-(height/2))/height)*zh*zoom)

            for x in range(width):
                zx = z_c_r+ (((x-(width/2))/width)*zw*zoom)

                # Mapping real -> complex plane
                z = complex(zx, zy)
                
                count = 0
                
                for i in range(niter):
                    # complex numerical derivative
                    dz = df(z)
                    if dz == 0:
                        break

                    count += 1
                    if count > 255:
                        break
                   
                    znext = z - f(z) / dz # Newton iteration

                    if abs(znext - z) < eps: # stop when close enough to any root
                        break
                    
                    z = znext

                # Pixels colored using the roots
                if abs(z-r1)<eps:
                    # color red
                    pixels[height-y-1,x] = (255 - count*multcol, 0, 0)
                elif abs(z-r2)<=eps:
                    # color green
                    pixels[height-y-1,x] = (0, 255 - count*multcol, 0)
                elif abs(z-r3)<=eps:
                    
                    pixels[height-y-1,x] = (0, 0, 255 - count*multcol)
                elif abs(z-r4)<=eps:
                    pixels[height-y-1,x] = (0, 255 - count*multcol, 255 - count*multcol)
                elif abs(z-r5)<=eps:
                    pixels[height-y-1,x] = ( 255 - count*multcol,0, 255 - count*multcol)
                elif abs(z-r6)<=eps:
                    pixels[height-y-1,x] = ( 255 - count*multcol, 255 - count*multcol,0)
                elif abs(z-r7)<=eps:
                    pixels[height-y-1,x] = ( 255 - count*multcol, 255 - count*multcol,255 - count*multcol)
                elif abs(z-r8)<=eps:
                    pixels[height-y-1,x] = ( 125,125,125)
                else:   
                    pixels[height-y-1,x] = (0, 0, 0)
 
    return pixels

def display3(z_c_r=0, z_c_i=0, zh = 1, zw=1, width=500, height=500, zoom=1,  niter=256):
    """ Display a newton-raphson fractal """
    print("Z region from (",z_c_r+ (((0-(width/2))/width)*zw*zoom),",",z_c_i+(((0-(height/2))/height)*zh*zoom) ,") to (",z_c_r+ (((width-(width/2))/width)*zw*zoom),",",z_c_i+(((height-(height/2))/height)*zh*zoom),")")
    pimg = newton_set1(z_c_r=z_c_r, z_c_i=z_c_i, zh = zh, zw=zw, width=width, height=width, zoom=zoom,  niter=niter)
    plt.title('Newton Fractal f(z)=z**8+15*z**4-16')
    plt.xlabel("real"+"("+ str(z_c_r+ (((0-(width/2))/width)*zw*zoom))+","+str(z_c_r+ (((width-(width/2))/width)*zw*zoom))+")")
    plt.ylabel("imaginary"+"("+str(z_c_i+(((0-(height/2))/height)*zh*zoom))+","+str(z_c_i+(((height-(height/2))/height)*zh*zoom)) +")")
    plt.imshow(pimg)
    plt.show()

# %% [markdown]
# **Gráfica**

# %%
x = np.linspace(-2.0,2.0,100)
fig, ax = plt.subplots()
ax.plot(x,f(x))
ax.axhline(y=0, color='k')
ax.axvline(x=0, color='k')
ax.grid(True, which='both')
plt.title('f(x)= x**8+15*x**4-16')
plt.xlabel('x')
plt.ylabel('f(x)')
# Out:
# Text(0, 0.5, 'f(x)')

# %%
print("zoom out")
display3(zoom=1)
display3(zoom=2)
display3(zoom=3)
display3(zoom=4)
display3(zoom=5)
# Out:
# zoom out
# Z region from ( -0.5 , -0.5 ) to ( 0.5 , 0.5 )
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Z region from ( -1.0 , -1.0 ) to ( 1.0 , 1.0 )
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Z region from ( -1.5 , -1.5 ) to ( 1.5 , 1.5 )
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Z region from ( -2.0 , -2.0 ) to ( 2.0 , 2.0 )
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Z region from ( -2.5 , -2.5 ) to ( 2.5 , 2.5 )
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# ###Newton iterates: z=10.0 + 0.0j

# %%
def fSegundo(z):
    return z**8+15*z**4-16

def dfSegundo(z):
    return 8*z**7+60*z**3

# %%
z=10.0 + 0.0j
r=[]
i=[]
for k in range(50):
  dz = dfSegundo(z)
  z = z - fSegundo(z) / dz # Newton iteration
  r.append(np.real(z))
  i.append(np.imag(z))
plt.title('Newton iterates: z=10.0 + 0.0j')
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imaginary part')
plt.show()

# %% [markdown]
# ###Newton iterates form z=-10.0 + 10.0j

# %%
z=-10.0 +10.0j
r=[]
i=[]
for k in range(50):
  dz = dfSegundo(z)
  z = z - fSegundo(z) / dz # Newton iteration
  r.append(np.real(z))
  i.append(np.imag(z))
plt.title('Newton iterates: z=-10.0 + 10.0j')
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imaginary part')
plt.show()

# %% [markdown]
# ###Newton iterates: z=-10.0 -10.0j

# %%
z=-10.0 - 10.0j
r=[]
i=[]
for k in range(100):
  dz = dfSegundo(z)
  z = z - fSegundo(z) / dz # Newton iteration
  r.append(np.real(z))
  i.append(np.imag(z))
plt.title('Newton iterates form z=10.0 + 10.0j')
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imagnary part')
plt.show()

# %% [markdown]
# ###Newton iterates: z=10.0 + 10.0j

# %%
z=10.0 + 10.0j
r=[]
i=[]
for k in range(100):
  dz = dfSegundo(z)
  z = z - fSegundo(z) / dz # Newton iteration
  r.append(np.real(z))
  i.append(np.imag(z))
plt.title('Newton iterates form z=10.0 + 10.0j')
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imaginary part')
plt.show()

# %% [markdown]
# ###Análisis de resultados
# ________________________________________
#
# *   Se trabajo el fractal generado a través del polinomio = z^8 + 15z^4 - 16
#
# *   Debido a que el polinomio es de grado 8, se encontraron ocho raíces en total, de las cuales dos son reales y ocho son complejas.
#
# *   En la gráfica del fractal es posible evidenciar ocho colores (en zonas amplias y delimitadas) correspondientes a los valores que convergen para cada una de las raíces. Además, los valores para las cuatro raíces representadas por los colores: cyan, azul, morado y amarillo tienen menos convergencia con respecto a las demás raices.

# %% [markdown]
# ##**Tercer Fractal**

# %%
import math
import matplotlib.pyplot as plt
import numpy as np
import cmath as cm


  

def f(z):
    return z**3-2*z+2


def df(z):
    return 3*z**2-2
    

def newton_set1(z_c_r=0, z_c_i=0, zh = 5, zw=5, width=500, height=500, zoom=1,  niter=256):
    """ Fractals using newton-raphson """

    # Pixels array
    pixels = np.arange(width*height*3, dtype=np.uint32).reshape(height, width, 3)

    h = 1e-7 # step size for numerical derivative
    eps = 1e-3 # max error allowed

    # Bounding roots
    r1 = -1.76929
    r2=complex(0.8846,0.589743)
    r3 = complex(0.884646,-0.589743)
    
    # Color multiplication factor
    # NOTE: Increasing this darkens the image and lightens it otherwise
    multcol = 5

    for y in range(height):
            zy =   z_c_i+(((y-(height/2))/height)*zh*zoom)

            for x in range(width):
                zx = z_c_r+ (((x-(width/2))/width)*zw*zoom)

                # Mapping real -> complex plane
                z = complex(zx, zy)
                
                count = 0
                
                for i in range(niter):
                    # complex numerical derivative
                    dz = df(z)
                    if dz == 0:
                        break

                    count += 1
                    if count > 255:
                        break
                   
                    znext = z - f(z) / dz # Newton iteration

                    if abs(znext - z) < eps: # stop when close enough to any root
                        break
                    
                    z = znext

                # Pixels colored using the roots
                if abs(z-r1)<eps:
                    # color red
                    pixels[height-y-1,x] = (255 - count*multcol, 0, 0)
                elif abs(z-r2)<=eps:
                    # color green
                    pixels[height-y-1,x] = (0, 255 - count*multcol, 0)
                elif abs(z-r3)<=eps:
                    
                    pixels[height-y-1,x] = (0, 0, 255 - count*multcol)
                
                else:   
                    pixels[height-y-1,x] = (0, 0, 0)
 
    return pixels

def display4(z_c_r=0, z_c_i=0, zh = 1, zw=1, width=500, height=500, zoom=1,  niter=256):
    """ Display a newton-raphson fractal """    
    print("Z region from (",z_c_r+ (((0-(width/2))/width)*zw*zoom),",",z_c_i+(((0-(height/2))/height)*zh*zoom) ,") to (",z_c_r+ (((width-(width/2))/width)*zw*zoom),",",z_c_i+(((height-(height/2))/height)*zh*zoom),")")
    pimg = newton_set1(z_c_r=z_c_r, z_c_i=z_c_i, zh = zh, zw=zw, width=width, height=width, zoom=zoom,  niter=niter)
    plt.title('Newton Fractal f(z)= z**3-2*z+2')
    plt.xlabel("real"+"("+ str(z_c_r+ (((0-(width/2))/width)*zw*zoom))+","+str(z_c_r+ (((width-(width/2))/width)*zw*zoom))+")")
    plt.ylabel("imaginary"+"("+str(z_c_i+(((0-(height/2))/height)*zh*zoom))+","+str(z_c_i+(((height-(height/2))/height)*zh*zoom)) +")")
    plt.imshow(pimg)
    plt.show()

# %% [markdown]
# **Gráfica**

# %%
x = np.linspace(-2.0,2.0,100)
fig, ax = plt.subplots()
ax.plot(x,f(x))
ax.axhline(y=0, color='k')
ax.axvline(x=0, color='k')
ax.grid(True, which='both')
plt.title('f(x)=x**3-2*x+2')
plt.xlabel('x')
plt.ylabel('f(x)')
# Out:
# Text(0, 0.5, 'f(x)')

# %%
print("zoom out")
display4(zoom=1)
display4(zoom=2)
display4(zoom=3)
display4(zoom=4)
display4(zoom=5)
# Out:
# zoom out
# Z region from ( -0.5 , -0.5 ) to ( 0.5 , 0.5 )
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Z region from ( -1.0 , -1.0 ) to ( 1.0 , 1.0 )
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Z region from ( -1.5 , -1.5 ) to ( 1.5 , 1.5 )
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Z region from ( -2.0 , -2.0 ) to ( 2.0 , 2.0 )
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Z region from ( -2.5 , -2.5 ) to ( 2.5 , 2.5 )
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# ###Newton iterates: z=10.0 + 0.0j

# %%
def fTercero(z):
    return z**3-2*z+2

def dfTercero(z):
    return 3*z**2-2

# %%
z=-10.0 +10.0j
r=[]
i=[]
for k in range(50):
  dz = dfTercero(z)
  z = z - fTercero(z) / dz # Newton iteration
  r.append(np.real(z))
  i.append(np.imag(z))
plt.title('Newton iterates: z=-10.0 + 10.0j')
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imaginary part')
plt.show()

# %% [markdown]
# ###Newton iterates form z=-10.0 + 10.0j

# %%
z=-10.0 +10.0j
r=[]
i=[]
for k in range(50):
  dz = dfTercero(z)
  z = z - fTercero(z) / dz # Newton iteration
  r.append(np.real(z))
  i.append(np.imag(z))
plt.title('Newton iterates: z=-10.0 + 10.0j')
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imaginary part')
plt.show()

# %% [markdown]
# ###Newton iterates: z=-10.0 -10.0j

# %%
z=-10.0 -10.0j
r=[]
i=[]
for k in range(50):
  dz = dfTercero(z)
  z = z - fTercero(z) / dz # Newton iteration
  r.append(np.real(z))
  i.append(np.imag(z))
plt.title('Newton iterates form z=-10.0 -10.0j')
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imagnary part')
plt.show()

# %% [markdown]
# ###Newton iterates: z=0.0 + 0.0j

# %%
z=0.0 + 0.0j
r=[]
i=[]
for k in range(100):
  dz = dfTercero(z)
  z = z - fTercero(z) / dz # Newton iteration
  r.append(np.real(z))
  i.append(np.imag(z))
plt.title('Newton iterates form z=10.0 + 10.0j')
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imagnary part')
plt.show()

# %% [markdown]
# ###Análisis de resultados
# ________________________________________
#
# *   Se trabajo el fractal generado a través del polinomio = z^3 - 2*z + 2
#
# *   Debido a que el polinomio es de grado 3, se encontraron tres raíces en total, de las cuales una es real y dos son complejas.
#
#
# *   En la gráfica del fractal es posible evidenciar tres colores (en grandes zonas) correspondientes a los valores que convergen para cada una de las raíces. Además, los valores para las dos raíces representadas por los colores: azul y verde tienen más convergencia con respecto a las demás raices.
